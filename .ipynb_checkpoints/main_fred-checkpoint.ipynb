# %%
! python fredmd/transform.py
# Out:
# --- Démarrage du traitement de fredmd/fredmd.csv ---
# Traitement des colonnes...
#
# --- Nettoyage du 'Ragged Edge' (fin de fichier) ---
# Suppression de 3 ligne(s) incomplète(s) à la fin du fichier (Ragged Edge).
# Lignes restantes : 801
#
# --- Rapport de validité des données ---
# (Affiche uniquement les colonnes où des données manquent au-delà de la transformation mathématique)
# Colonne 'PERMIT' (Code 4) : Incomplète jusqu'au 1959-12-01. (Valide dès 1960-01-01)
# Colonne 'PERMITNE' (Code 4) : Incomplète jusqu'au 1959-12-01. (Valide dès 1960-01-01)
# Colonne 'PERMITMW' (Code 4) : Incomplète jusqu'au 1959-12-01. (Valide dès 1960-01-01)
# Colonne 'PERMITS' (Code 4) : Incomplète jusqu'au 1959-12-01. (Valide dès 1960-01-01)
# Colonne 'PERMITW' (Code 4) : Incomplète jusqu'au 1959-12-01. (Valide dès 1960-01-01)
# Colonne 'ACOGNO' (Code 5) : Incomplète jusqu'au 1992-02-01. (Valide dès 1992-03-01)
# Colonne 'ANDENOx' (Code 5) : Incomplète jusqu'au 1968-02-01. (Valide dès 1968-03-01)
# Colonne 'CP3Mx' (Code 2) : Incomplète jusqu'au 2020-05-01. (Valide dès 2020-06-01)
# Colonne 'COMPAPFFx' (Code 1) : Incomplète jusqu'au 2020-04-01. (Valide dès 2020-05-01)
# Colonne 'TWEXAFEGSMTHx' (Code 5) : Incomplète jusqu'au 1973-01-01. (Valide dès 1973-02-01)
# Colonne 'UMCSENTx' (Code 2) : Incomplète jusqu'au 1978-01-01. (Valide dès 1978-02-01)
# Colonne 'VIXCLSx' (Code 1) : Incomplète jusqu'au 1962-06-01. (Valide dès 1962-07-01)
#
# --- Terminé. Fichier sauvegardé : fredmd/nice_fredmd.csv ---

# %% [markdown]
# # Comparing Models one month ahead forecast between 2013 and 2019

# %%
from model import *
import numpy as np

import pandas as pd
data = pd.read_csv('fredmd/nice_fredmd.csv')
data.set_index('sasdate', inplace=True)
data.index = pd.to_datetime(data.index)
data = data[data.index >= "1970"]
data = data[data.index < "2020"]
cols_with_nan = data.columns[data.isna().any()].tolist()
if len(cols_with_nan) > 0:
    print(f"--- {len(cols_with_nan)} Colonnes with NaN to deleate ---")
    for col in cols_with_nan:
        print(f"- {col}")
else:
    print("No NaN detected.")
data = data.dropna(axis=1)

from dataloader import MacroDataLoader

X_col = list(data.columns)
Y_col = ['RPI', 'CPIAUCSL', 'UNRATE', 'GS10']
cfg = {
    'date_col': 'sasdate',
    'country_col': None,
    'target_col': Y_col,
    'features': X_col
}
loader = MacroDataLoader(data, cfg)

models_dict = {
    'RNN': make_builder(RNNModel, base_config=config_rnn, weight_decay=1e-2),
    'NODE': make_builder(LatentNODEModel, base_config=config_node, weight_decay=1e-2),
    'FVAR': build_fvar,
    'ESN': build_esn_panel,
    'OLS-VAR': build_var,
    'Ridge-VAR': build_ridge_cv,
    'RF': build_rf_panel,
    'Minnesota-VAR': build_minnesota_ridge,
}

from evaluator import UniFreqPanelMacroEvaluator

evaluator = UniFreqPanelMacroEvaluator(
    dataloader=loader,
    models_builders=models_dict,
    horizon=2,
    verbose=True,
    metric='rmse'
)

backtest_dates = pd.date_range(start='2013-01', periods=12*6, freq='ME')

results = evaluator.run_backtesting(
    end_train_date_list=backtest_dates,
    num_exp_by_fit=12
)

evaluator.print_significance_tests(results, target_idx=None, horizon_idx=0)

for i in range(len(cfg['target_col'])):
    print(f"\n cfg['target_col'][i]")
    evaluator.print_significance_tests(results, target_idx=i, horizon_idx=0)

# Plot for horizon > 1
# evaluator.plot_compare_models(results, target_idx=None, title=f"RMSE Forecast Evolution Average")

# for i in range(len(cfg['target_col'])):
#     evaluator.plot_compare_models(results, target_idx=i, title=f"RMSE Forecast Evolution - {cfg['target_col'][i]}")
# Out:
# --- 3 Colonnes with NaN to deleate ---
# - ACOGNO
# - TWEXAFEGSMTHx
# - UMCSENTx
# [MacroDataLoader] Initialized: 1 entities, 600 obs, 123 features.
#
# [Backtest] Model: RNN
#
# [Backtest] Model: NODE
#
# [Backtest] Model: FVAR
#
# [Backtest] Model: ESN
#
# [Backtest] Model: OLS-VAR
#
# [Backtest] Model: Ridge-VAR
#
# [Backtest] Model: RF
#
# [Backtest] Model: Minnesota-VAR
#
# ====================================================================================================
# STATISTICAL SIGNIFICANCE TESTS
#   Target  : All Targets (sum)
#   Horizon : H1
# ====================================================================================================
#
# 1. FRIEDMAN TEST  (Non-parametric, multiple models)
# ----------------------------------------------------------------------------------------------------
# Statistic : 103.5787
# p-value   : 0.0000  →  ✓ Significant (α=0.05)
#
# Mean Ranks (lower = better):
#         Model  Mean Rank  Mean RMSE
# Minnesota-VAR   3.652778   1.117948
#           ESN   3.875000   1.121476
#           RNN   3.902778   1.120954
#          FVAR   4.222222   1.162142
#     Ridge-VAR   4.319444   1.143179
#          NODE   4.361111   1.165480
#            RF   4.513889   1.169553
#       OLS-VAR   7.152778   1.874022
#
#
# 2. DIEBOLD-MARIANO PAIRWISE TESTS
# ----------------------------------------------------------------------------------------------------
#   Model 1       Model 2 Horizon  RMSE M1  RMSE M2  DM Statistic      p-value Significant        Winner
#       ESN       OLS-VAR      H1 1.224800 2.015546     -7.396071 1.403322e-13         Yes           ESN
#   OLS-VAR     Ridge-VAR      H1 2.015546 1.233566      7.260026 3.870237e-13         Yes     Ridge-VAR
#   OLS-VAR Minnesota-VAR      H1 2.015546 1.242484      7.167094 7.660539e-13         Yes Minnesota-VAR
#       RNN       OLS-VAR      H1 1.238193 2.015546     -7.037158 1.961986e-12         Yes           RNN
#      FVAR       OLS-VAR      H1 1.262718 2.015546     -6.770153 1.286460e-11         Yes          FVAR
#   OLS-VAR            RF      H1 2.015546 1.284101      6.295339 3.067278e-10         Yes            RF
#      NODE       OLS-VAR      H1 1.284972 2.015546     -6.279961 3.386575e-10         Yes          NODE
#       ESN            RF      H1 1.224800 1.284101     -1.652786 9.837442e-02          No           Tie
#      NODE           ESN      H1 1.284972 1.224800      1.626134 1.039211e-01          No           Tie
#       RNN            RF      H1 1.238193 1.284101     -1.511637 1.306263e-01          No           Tie
#       RNN          NODE      H1 1.238193 1.284972     -1.494361 1.350812e-01          No           Tie
# Ridge-VAR            RF      H1 1.233566 1.284101     -1.056070 2.909365e-01          No           Tie
#      NODE     Ridge-VAR      H1 1.284972 1.233566      1.052840 2.924141e-01          No           Tie
#      NODE Minnesota-VAR      H1 1.284972 1.242484      1.021997 3.067823e-01          No           Tie
#        RF Minnesota-VAR      H1 1.284101 1.242484      0.979116 3.275225e-01          No           Tie
#      FVAR           ESN      H1 1.262718 1.224800      0.839831 4.010032e-01          No           Tie
#      FVAR     Ridge-VAR      H1 1.262718 1.233566      0.665755 5.055675e-01          No           Tie
#       RNN          FVAR      H1 1.238193 1.262718     -0.605747 5.446830e-01          No           Tie
#       RNN           ESN      H1 1.238193 1.224800      0.592474 5.535333e-01          No           Tie
#      NODE          FVAR      H1 1.284972 1.262718      0.477088 6.332992e-01          No           Tie
#      FVAR            RF      H1 1.262718 1.284101     -0.460746 6.449809e-01          No           Tie
#      FVAR Minnesota-VAR      H1 1.262718 1.242484      0.453175 6.504230e-01          No           Tie
#       ESN Minnesota-VAR      H1 1.224800 1.242484     -0.423557 6.718888e-01          No           Tie
#       ESN     Ridge-VAR      H1 1.224800 1.233566     -0.247123 8.048132e-01          No           Tie
# Ridge-VAR Minnesota-VAR      H1 1.233566 1.242484     -0.198487 8.426637e-01          No           Tie
#       RNN     Ridge-VAR      H1 1.238193 1.233566      0.141731 8.872925e-01          No           Tie
#       RNN Minnesota-VAR      H1 1.238193 1.242484     -0.108488 9.136082e-01          No           Tie
#      NODE            RF      H1 1.284972 1.284101      0.095824 9.236606e-01          No           Tie
#
# ====================================================================================================
# Interpretation:
#   • Friedman    : Tests whether ANY models differ significantly.
#   • DM tests    : Identifies which specific pairs differ.
#   • DM stat < 0 : Model 1 better;  DM stat > 0 : Model 2 better.
#   • Errors summed across all targets.
# ====================================================================================================
#
# ====================================================================================================
# STATISTICAL SIGNIFICANCE TESTS
#   Target  : Target 0
#   Horizon : H1
# ====================================================================================================
#
# 1. FRIEDMAN TEST  (Non-parametric, multiple models)
# ----------------------------------------------------------------------------------------------------
# Statistic : 81.9120
# p-value   : 0.0000  →  ✓ Significant (α=0.05)
#
# Mean Ranks (lower = better):
#         Model  Mean Rank  Mean RMSE
#          NODE   3.513889   0.287852
#          FVAR   3.611111   0.307178
#           RNN   3.958333   0.317927
#            RF   4.097222   0.321715
# Minnesota-VAR   4.541667   0.367699
#           ESN   4.736111   0.366131
#     Ridge-VAR   4.958333   0.391615
#       OLS-VAR   6.583333   0.897700
#
#
# 2. DIEBOLD-MARIANO PAIRWISE TESTS
# ----------------------------------------------------------------------------------------------------
#   Model 1       Model 2 Horizon  RMSE M1  RMSE M2  DM Statistic      p-value Significant        Winner
#       ESN       OLS-VAR      H1 0.455509 1.086311     -5.765455 8.143777e-09         Yes           ESN
#       RNN       OLS-VAR      H1 0.424350 1.086311     -5.674709 1.389243e-08         Yes           RNN
#      NODE       OLS-VAR      H1 0.399324 1.086311     -5.669120 1.435325e-08         Yes          NODE
#   OLS-VAR            RF      H1 1.086311 0.430021      5.549090 2.871596e-08         Yes            RF
#      FVAR       OLS-VAR      H1 0.435098 1.086311     -5.383973 7.285955e-08         Yes          FVAR
#   OLS-VAR Minnesota-VAR      H1 1.086311 0.518679      5.245649 1.557328e-07         Yes Minnesota-VAR
#   OLS-VAR     Ridge-VAR      H1 1.086311 0.508481      5.184647 2.164246e-07         Yes     Ridge-VAR
#      NODE     Ridge-VAR      H1 0.399324 0.508481     -3.307807 9.402945e-04         Yes          NODE
#       RNN     Ridge-VAR      H1 0.424350 0.508481     -2.773519 5.545358e-03         Yes           RNN
# Ridge-VAR            RF      H1 0.508481 0.430021      2.188974 2.859874e-02         Yes            RF
#      FVAR     Ridge-VAR      H1 0.435098 0.508481     -2.129209 3.323696e-02         Yes          FVAR
#      NODE            RF      H1 0.399324 0.430021     -2.113800 3.453232e-02         Yes          NODE
#      NODE          FVAR      H1 0.399324 0.435098     -1.901648 5.721725e-02          No           Tie
#      NODE           ESN      H1 0.399324 0.455509     -1.802166 7.151923e-02          No           Tie
#       ESN     Ridge-VAR      H1 0.455509 0.508481     -1.598109 1.100187e-01          No           Tie
#      NODE Minnesota-VAR      H1 0.399324 0.518679     -1.343802 1.790125e-01          No           Tie
#       RNN Minnesota-VAR      H1 0.424350 0.518679     -1.238262 2.156188e-01          No           Tie
#       RNN          NODE      H1 0.424350 0.399324      1.172292 2.410798e-01          No           Tie
#       RNN           ESN      H1 0.424350 0.455509     -1.055898 2.910147e-01          No           Tie
#        RF Minnesota-VAR      H1 0.430021 0.518679     -1.043665 2.966404e-01          No           Tie
#      FVAR Minnesota-VAR      H1 0.435098 0.518679     -0.961244 3.364294e-01          No           Tie
#       ESN Minnesota-VAR      H1 0.455509 0.518679     -0.792832 4.278759e-01          No           Tie
#       ESN            RF      H1 0.455509 0.430021      0.738557 4.601758e-01          No           Tie
#      FVAR           ESN      H1 0.435098 0.455509     -0.544494 5.861013e-01          No           Tie
#       RNN          FVAR      H1 0.424350 0.435098     -0.339621 7.341423e-01          No           Tie
#       RNN            RF      H1 0.424350 0.430021     -0.278890 7.803295e-01          No           Tie
#      FVAR            RF      H1 0.435098 0.430021      0.198045 8.430101e-01          No           Tie
# Ridge-VAR Minnesota-VAR      H1 0.508481 0.518679     -0.154868 8.769254e-01          No           Tie
#
# ====================================================================================================
# Interpretation:
#   • Friedman    : Tests whether ANY models differ significantly.
#   • DM tests    : Identifies which specific pairs differ.
#   • DM stat < 0 : Model 1 better;  DM stat > 0 : Model 2 better.
# ====================================================================================================
#
# ====================================================================================================
# STATISTICAL SIGNIFICANCE TESTS
#   Target  : Target 1
#   Horizon : H1
# ====================================================================================================
#
# 1. FRIEDMAN TEST  (Non-parametric, multiple models)
# ----------------------------------------------------------------------------------------------------
# Statistic : 40.5787
# p-value   : 0.0000  →  ✓ Significant (α=0.05)
#
# Mean Ranks (lower = better):
#         Model  Mean Rank  Mean RMSE
# Minnesota-VAR   3.708333   0.486904
#           ESN   3.944444   0.511371
#           RNN   4.277778   0.517275
#          FVAR   4.305556   0.556744
#     Ridge-VAR   4.513889   0.544810
#          NODE   4.611111   0.569989
#            RF   4.611111   0.576661
#       OLS-VAR   6.027778   0.877923
#
#
# 2. DIEBOLD-MARIANO PAIRWISE TESTS
# ----------------------------------------------------------------------------------------------------
#   Model 1       Model 2 Horizon  RMSE M1  RMSE M2  DM Statistic  p-value Significant        Winner
#   OLS-VAR     Ridge-VAR      H1 1.031949 0.700690      3.968592 0.000072         Yes     Ridge-VAR
#   OLS-VAR Minnesota-VAR      H1 1.031949 0.681444      3.719527 0.000200         Yes Minnesota-VAR
#      FVAR       OLS-VAR      H1 0.716548 1.031949     -3.491633 0.000480         Yes          FVAR
#       RNN       OLS-VAR      H1 0.710544 1.031949     -3.454680 0.000551         Yes           RNN
#       ESN       OLS-VAR      H1 0.706711 1.031949     -3.290257 0.001001         Yes           ESN
#      NODE Minnesota-VAR      H1 0.793823 0.681444      2.548143 0.010830         Yes Minnesota-VAR
#        RF Minnesota-VAR      H1 0.795304 0.681444      2.505615 0.012224         Yes Minnesota-VAR
#      NODE       OLS-VAR      H1 0.793823 1.031949     -2.161426 0.030662         Yes          NODE
#   OLS-VAR            RF      H1 1.031949 0.795304      2.142217 0.032176         Yes            RF
#       RNN          NODE      H1 0.710544 0.793823     -2.101570 0.035591         Yes           RNN
#       RNN            RF      H1 0.710544 0.795304     -2.097120 0.035983         Yes           RNN
#      NODE           ESN      H1 0.793823 0.706711      1.885936 0.059304          No           Tie
#       ESN            RF      H1 0.706711 0.795304     -1.884745 0.059464          No           Tie
#      NODE     Ridge-VAR      H1 0.793823 0.700690      1.519739 0.128577          No           Tie
# Ridge-VAR            RF      H1 0.700690 0.795304     -1.517411 0.129163          No           Tie
#       RNN Minnesota-VAR      H1 0.710544 0.681444      1.411789 0.158012          No           Tie
#      FVAR            RF      H1 0.716548 0.795304     -1.014043 0.310562          No           Tie
#      NODE          FVAR      H1 0.793823 0.716548      1.008196 0.313360          No           Tie
#       ESN Minnesota-VAR      H1 0.706711 0.681444      0.975082 0.329520          No           Tie
#      FVAR Minnesota-VAR      H1 0.716548 0.681444      0.712593 0.476098          No           Tie
# Ridge-VAR Minnesota-VAR      H1 0.700690 0.681444      0.601532 0.547486          No           Tie
#      FVAR     Ridge-VAR      H1 0.716548 0.700690      0.362092 0.717283          No           Tie
#      NODE            RF      H1 0.793823 0.795304     -0.314771 0.752936          No           Tie
#       RNN     Ridge-VAR      H1 0.710544 0.700690      0.304713 0.760585          No           Tie
#      FVAR           ESN      H1 0.716548 0.706711      0.196734 0.844036          No           Tie
#       ESN     Ridge-VAR      H1 0.706711 0.700690      0.142078 0.887018          No           Tie
#       RNN           ESN      H1 0.710544 0.706711      0.140765 0.888056          No           Tie
#       RNN          FVAR      H1 0.710544 0.716548     -0.118276 0.905849          No           Tie
#
# ====================================================================================================
# Interpretation:
#   • Friedman    : Tests whether ANY models differ significantly.
#   • DM tests    : Identifies which specific pairs differ.
#   • DM stat < 0 : Model 1 better;  DM stat > 0 : Model 2 better.
# ====================================================================================================
#
# ====================================================================================================
# STATISTICAL SIGNIFICANCE TESTS
#   Target  : Target 2
#   Horizon : H1
# ====================================================================================================
#
# 1. FRIEDMAN TEST  (Non-parametric, multiple models)
# ----------------------------------------------------------------------------------------------------
# Statistic : 6.4537
# p-value   : 0.4879  →  ✗ Not significant (α=0.05)
#
# Mean Ranks (lower = better):
#         Model  Mean Rank  Mean RMSE
#     Ridge-VAR   4.069444   0.580433
#           ESN   4.194444   0.611912
# Minnesota-VAR   4.402778   0.616248
#          FVAR   4.472222   0.621651
#            RF   4.527778   0.635764
#           RNN   4.694444   0.635453
#          NODE   4.763889   0.644104
#       OLS-VAR   4.875000   0.759837
#
#
# 2. DIEBOLD-MARIANO PAIRWISE TESTS
# ----------------------------------------------------------------------------------------------------
#   Model 1       Model 2 Horizon  RMSE M1  RMSE M2  DM Statistic  p-value Significant        Winner
#       ESN       OLS-VAR      H1 0.720185 0.981353     -2.645552 0.008156         Yes           ESN
#   OLS-VAR     Ridge-VAR      H1 0.981353 0.711390      2.538103 0.011146         Yes     Ridge-VAR
#   OLS-VAR Minnesota-VAR      H1 0.981353 0.734177      2.467426 0.013609         Yes Minnesota-VAR
#       RNN       OLS-VAR      H1 0.756554 0.981353     -2.183877 0.028971         Yes           RNN
#   OLS-VAR            RF      H1 0.981353 0.763662      2.062951 0.039117         Yes            RF
#      FVAR       OLS-VAR      H1 0.770525 0.981353     -1.977324 0.048005         Yes          FVAR
#      NODE       OLS-VAR      H1 0.783659 0.981353     -1.871510 0.061274          No           Tie
#      NODE            RF      H1 0.783659 0.763662      1.855279 0.063556          No           Tie
#      NODE Minnesota-VAR      H1 0.783659 0.734177      1.783972 0.074428          No           Tie
#      NODE     Ridge-VAR      H1 0.783659 0.711390      1.635425 0.101960          No           Tie
#      NODE           ESN      H1 0.783659 0.720185      1.610371 0.107317          No           Tie
#       RNN Minnesota-VAR      H1 0.756554 0.734177      1.464246 0.143127          No           Tie
#       RNN           ESN      H1 0.756554 0.720185      1.457832 0.144887          No           Tie
#      FVAR     Ridge-VAR      H1 0.770525 0.711390      1.259391 0.207889          No           Tie
#       RNN     Ridge-VAR      H1 0.756554 0.711390      1.258902 0.208066          No           Tie
#      FVAR Minnesota-VAR      H1 0.770525 0.734177      1.255937 0.209139          No           Tie
# Ridge-VAR            RF      H1 0.711390 0.763662     -1.227707 0.219557          No           Tie
#      FVAR           ESN      H1 0.770525 0.720185      1.220192 0.222392          No           Tie
#        RF Minnesota-VAR      H1 0.763662 0.734177      1.179920 0.238032          No           Tie
#       ESN            RF      H1 0.720185 0.763662     -1.149353 0.250410          No           Tie
#       RNN          NODE      H1 0.756554 0.783659     -0.977455 0.328344          No           Tie
#      NODE          FVAR      H1 0.783659 0.770525      0.856546 0.391696          No           Tie
# Ridge-VAR Minnesota-VAR      H1 0.711390 0.734177     -0.662366 0.507737          No           Tie
#       ESN Minnesota-VAR      H1 0.720185 0.734177     -0.636603 0.524384          No           Tie
#       RNN          FVAR      H1 0.756554 0.770525     -0.468877 0.639158          No           Tie
#      FVAR            RF      H1 0.770525 0.763662      0.388212 0.697859          No           Tie
#       RNN            RF      H1 0.756554 0.763662     -0.291621 0.770577          No           Tie
#       ESN     Ridge-VAR      H1 0.720185 0.711390      0.271831 0.785752          No           Tie
#
# ====================================================================================================
# Interpretation:
#   • Friedman    : Tests whether ANY models differ significantly.
#   • DM tests    : Identifies which specific pairs differ.
#   • DM stat < 0 : Model 1 better;  DM stat > 0 : Model 2 better.
# ====================================================================================================
#
# ====================================================================================================
# STATISTICAL SIGNIFICANCE TESTS
#   Target  : Target 3
#   Horizon : H1
# ====================================================================================================
#
# 1. FRIEDMAN TEST  (Non-parametric, multiple models)
# ----------------------------------------------------------------------------------------------------
# Statistic : 30.8241
# p-value   : 0.0001  →  ✓ Significant (α=0.05)
#
# Mean Ranks (lower = better):
#         Model  Mean Rank  Mean RMSE
#            RF   3.902778   0.392259
#          NODE   4.041667   0.391010
#     Ridge-VAR   4.055556   0.405132
#          FVAR   4.361111   0.441617
# Minnesota-VAR   4.527778   0.419457
#           RNN   4.625000   0.424414
#           ESN   4.666667   0.423772
#       OLS-VAR   5.819444   0.728684
#
#
# 2. DIEBOLD-MARIANO PAIRWISE TESTS
# ----------------------------------------------------------------------------------------------------
#   Model 1       Model 2 Horizon  RMSE M1  RMSE M2  DM Statistic      p-value Significant        Winner
#   OLS-VAR Minnesota-VAR      H1 0.924328 0.520918      4.964886 6.874158e-07         Yes Minnesota-VAR
#   OLS-VAR            RF      H1 0.924328 0.498306      4.860908 1.168485e-06         Yes            RF
#      NODE       OLS-VAR      H1 0.497410 0.924328     -4.830737 1.360285e-06         Yes          NODE
#   OLS-VAR     Ridge-VAR      H1 0.924328 0.515839      4.733532 2.206458e-06         Yes     Ridge-VAR
#       RNN       OLS-VAR      H1 0.525167 0.924328     -4.720084 2.357474e-06         Yes           RNN
#       ESN       OLS-VAR      H1 0.523964 0.924328     -4.660133 3.160057e-06         Yes           ESN
#      FVAR       OLS-VAR      H1 0.545891 0.924328     -4.229995 2.336970e-05         Yes          FVAR
#      FVAR            RF      H1 0.545891 0.498306      1.677511 9.344261e-02          No           Tie
#      NODE          FVAR      H1 0.497410 0.545891     -1.659760 9.696268e-02          No           Tie
#       RNN          NODE      H1 0.525167 0.497410      1.114437 2.650917e-01          No           Tie
#       RNN            RF      H1 0.525167 0.498306      1.113154 2.656422e-01          No           Tie
#      FVAR     Ridge-VAR      H1 0.545891 0.515839      1.093167 2.743207e-01          No           Tie
#      NODE           ESN      H1 0.497410 0.523964     -1.046606 2.952812e-01          No           Tie
#       ESN            RF      H1 0.523964 0.498306      1.004710 3.150366e-01          No           Tie
#      FVAR Minnesota-VAR      H1 0.545891 0.520918      0.795041 4.265896e-01          No           Tie
#      NODE Minnesota-VAR      H1 0.497410 0.520918     -0.780667 4.349983e-01          No           Tie
#        RF Minnesota-VAR      H1 0.498306 0.520918     -0.760717 4.468263e-01          No           Tie
#      FVAR           ESN      H1 0.545891 0.523964      0.677655 4.979904e-01          No           Tie
# Ridge-VAR            RF      H1 0.515839 0.498306      0.647522 5.172942e-01          No           Tie
#      NODE     Ridge-VAR      H1 0.497410 0.515839     -0.626458 5.310147e-01          No           Tie
#       RNN          FVAR      H1 0.525167 0.545891     -0.623907 5.326889e-01          No           Tie
#       RNN     Ridge-VAR      H1 0.525167 0.515839      0.426865 6.694775e-01          No           Tie
#       ESN     Ridge-VAR      H1 0.523964 0.515839      0.365597 7.146657e-01          No           Tie
# Ridge-VAR Minnesota-VAR      H1 0.515839 0.520918     -0.207333 8.357498e-01          No           Tie
#       RNN Minnesota-VAR      H1 0.525167 0.520918      0.187101 8.515816e-01          No           Tie
#       ESN Minnesota-VAR      H1 0.523964 0.520918      0.154433 8.772684e-01          No           Tie
#      NODE            RF      H1 0.497410 0.498306     -0.130151 8.964467e-01          No           Tie
#       RNN           ESN      H1 0.525167 0.523964      0.082915 9.339193e-01          No           Tie
#
# ====================================================================================================
# Interpretation:
#   • Friedman    : Tests whether ANY models differ significantly.
#   • DM tests    : Identifies which specific pairs differ.
#   • DM stat < 0 : Model 1 better;  DM stat > 0 : Model 2 better.
# ====================================================================================================

# %% [markdown]
# # For covid crisis, between 2020-01 and 2021-10

# %%
from model import *
import numpy as np

import pandas as pd
data = pd.read_csv('fredmd/nice_fredmd.csv')
data.set_index('sasdate', inplace=True)
data.index = pd.to_datetime(data.index)
data = data[data.index >= "1970"]
data = data[data.index < "2022"]
cols_with_nan = data.columns[data.isna().any()].tolist()
if len(cols_with_nan) > 0:
    print(f"--- {len(cols_with_nan)} Colonnes with NaN to deleate ---")
    for col in cols_with_nan:
        print(f"- {col}")
else:
    print("No NaN detected.")
data = data.dropna(axis=1)

from dataloader import MacroDataLoader

X_col = list(data.columns)
Y_col = ['RPI', 'CPIAUCSL', 'UNRATE', 'GS10']
cfg = {
    'date_col': 'sasdate',
    'country_col': None,
    'target_col': Y_col,
    'features': X_col
}
loader = MacroDataLoader(data, cfg)

models_dict = {
    'RNN': make_builder(RNNModel, base_config=config_rnn, weight_decay=1e-2),
    'NODE': make_builder(LatentNODEModel, base_config=config_node, weight_decay=1e-2),
    'FVAR': build_fvar,
    'ESN': build_esn_panel,
    'OLS-VAR': build_var,
    'Ridge-VAR': build_ridge_cv,
    'RF': build_rf_panel,
    'Minnesota-VAR': build_minnesota_ridge,
    }

from evaluator import UniFreqPanelMacroEvaluator

evaluator_crisis = UniFreqPanelMacroEvaluator(
    dataloader=loader,
    models_builders=models_dict,
    horizon=2,
    verbose=True,
    metric='rmse'
)

backtest_dates = pd.date_range(start='2020-01', periods=22, freq='ME')

results_crisis = evaluator_crisis.run_backtesting(
    end_train_date_list=backtest_dates,
    num_exp_by_fit=6
)

print('\n Average')

evaluator_crisis.print_significance_tests(results_crisis, target_idx=None, horizon_idx=0)

for i in range(len(cfg['target_col'])):
    print(f"\n cfg['target_col'][i]")
    evaluator.print_significance_tests(results_crisis, target_idx=i, horizon_idx=0)

# evaluator.plot_compare_models(results_crisis, target_idx=None, title=f"RMSE Forecast Evolution Average")

# for i in range(len(cfg['target_col'])):
#     evaluator.plot_compare_models(results_crisis, target_idx=i, title=f"RMSE Forecast Evolution - {cfg['target_col'][i]}")
# Out:
# --- 5 Colonnes with NaN to deleate ---
# - ACOGNO
# - CP3Mx
# - COMPAPFFx
# - TWEXAFEGSMTHx
# - UMCSENTx
# [MacroDataLoader] Initialized: 1 entities, 624 obs, 121 features.
#
# [Backtest] Model: RNN
#
# [Backtest] Model: NODE
#
# [Backtest] Model: FVAR
#
# [Backtest] Model: ESN
#
# [Backtest] Model: OLS-VAR
#
# [Backtest] Model: Ridge-VAR
#
# [Backtest] Model: RF
#
# [Backtest] Model: Minnesota-VAR
#
#  Average
#
# ====================================================================================================
# STATISTICAL SIGNIFICANCE TESTS
#   Target  : All Targets (sum)
#   Horizon : H1
# ====================================================================================================
#
# 1. FRIEDMAN TEST  (Non-parametric, multiple models)
# ----------------------------------------------------------------------------------------------------
# Statistic : 38.4394
# p-value   : 0.0000  →  ✓ Significant (α=0.05)
#
# Mean Ranks (lower = better):
#         Model  Mean Rank  Mean RMSE
#           RNN   3.090909   7.078973
#          NODE   3.454545   7.214385
#            RF   3.727273   6.943604
# Minnesota-VAR   3.727273   7.236105
#           ESN   4.727273   7.328102
#     Ridge-VAR   5.227273   7.822937
#          FVAR   5.318182   8.921976
#       OLS-VAR   6.727273   9.779369
#
#
# 2. DIEBOLD-MARIANO PAIRWISE TESTS
# ----------------------------------------------------------------------------------------------------
#   Model 1       Model 2 Horizon   RMSE M1   RMSE M2  DM Statistic  p-value Significant        Winner
#      FVAR Minnesota-VAR      H1 15.130871 14.272893      3.413999 0.000640         Yes Minnesota-VAR
#   OLS-VAR Minnesota-VAR      H1 15.616027 14.272893      3.184617 0.001449         Yes Minnesota-VAR
#   OLS-VAR            RF      H1 15.616027 14.169555      2.847328 0.004409         Yes            RF
#      FVAR            RF      H1 15.130871 14.169555      2.686908 0.007212         Yes            RF
#       RNN       OLS-VAR      H1 14.391344 15.616027     -2.549012 0.010803         Yes           RNN
#   OLS-VAR     Ridge-VAR      H1 15.616027 14.714153      2.398107 0.016480         Yes     Ridge-VAR
# Ridge-VAR Minnesota-VAR      H1 14.714153 14.272893      2.366207 0.017971         Yes Minnesota-VAR
#      NODE       OLS-VAR      H1 14.505959 15.616027     -2.307204 0.021043         Yes          NODE
#      NODE            RF      H1 14.505959 14.169555      2.254256 0.024180         Yes            RF
# Ridge-VAR            RF      H1 14.714153 14.169555      2.246305 0.024684         Yes            RF
#       RNN          NODE      H1 14.391344 14.505959     -2.233334 0.025527         Yes           RNN
#       ESN            RF      H1 14.541077 14.169555      2.207961 0.027247         Yes            RF
#       RNN          FVAR      H1 14.391344 15.130871     -2.085381 0.037035         Yes           RNN
#       ESN       OLS-VAR      H1 14.541077 15.616027     -2.071879 0.038277         Yes           ESN
#       RNN            RF      H1 14.391344 14.169555      1.840027 0.065764          No           Tie
#      NODE          FVAR      H1 14.505959 15.130871     -1.712562 0.086793          No           Tie
#       RNN     Ridge-VAR      H1 14.391344 14.714153     -1.667166 0.095481          No           Tie
#       RNN           ESN      H1 14.391344 14.541077     -1.588207 0.112239          No           Tie
#      FVAR           ESN      H1 15.130871 14.541077      1.516461 0.129403          No           Tie
#      FVAR     Ridge-VAR      H1 15.130871 14.714153      1.423094 0.154709          No           Tie
#      FVAR       OLS-VAR      H1 15.130871 15.616027     -1.045423 0.295827          No           Tie
#      NODE     Ridge-VAR      H1 14.505959 14.714153     -1.018388 0.308494          No           Tie
#      NODE Minnesota-VAR      H1 14.505959 14.272893      0.906209 0.364825          No           Tie
#       ESN Minnesota-VAR      H1 14.541077 14.272893      0.902315 0.366890          No           Tie
#       ESN     Ridge-VAR      H1 14.541077 14.714153     -0.672603 0.501200          No           Tie
#      NODE           ESN      H1 14.505959 14.541077     -0.597704 0.550037          No           Tie
#       RNN Minnesota-VAR      H1 14.391344 14.272893      0.524159 0.600168          No           Tie
#        RF Minnesota-VAR      H1 14.169555 14.272893     -0.481866 0.629901          No           Tie
#
# ====================================================================================================
# Interpretation:
#   • Friedman    : Tests whether ANY models differ significantly.
#   • DM tests    : Identifies which specific pairs differ.
#   • DM stat < 0 : Model 1 better;  DM stat > 0 : Model 2 better.
#   • Errors summed across all targets.
# ====================================================================================================
# RPI
#
# ====================================================================================================
# STATISTICAL SIGNIFICANCE TESTS
#   Target  : Target 0
#   Horizon : H1
# ====================================================================================================
#
# 1. FRIEDMAN TEST  (Non-parametric, multiple models)
# ----------------------------------------------------------------------------------------------------
# Statistic : 24.1061
# p-value   : 0.0011  →  ✓ Significant (α=0.05)
#
# Mean Ranks (lower = better):
#         Model  Mean Rank  Mean RMSE
#           RNN   3.636364   4.255795
#          NODE   3.681818   4.306829
# Minnesota-VAR   3.818182   4.023036
#            RF   4.000000   3.999035
#          FVAR   4.636364   4.656641
#           ESN   4.772727   4.455478
#     Ridge-VAR   4.909091   4.398875
#       OLS-VAR   6.545455   6.289429
#
#
# 2. DIEBOLD-MARIANO PAIRWISE TESTS
# ----------------------------------------------------------------------------------------------------
#   Model 1       Model 2 Horizon  RMSE M1  RMSE M2  DM Statistic  p-value Significant        Winner
#   OLS-VAR            RF      H1 9.047031 6.934338      2.685532 0.007241         Yes            RF
#   OLS-VAR Minnesota-VAR      H1 9.047031 7.105020      2.581878 0.009826         Yes Minnesota-VAR
#      FVAR            RF      H1 7.612386 6.934338      2.551475 0.010727         Yes            RF
#       RNN          NODE      H1 7.380917 7.479765     -2.401728 0.016318         Yes           RNN
#       RNN       OLS-VAR      H1 7.380917 9.047031     -2.345609 0.018996         Yes           RNN
#      FVAR Minnesota-VAR      H1 7.612386 7.105020      2.276438 0.022820         Yes Minnesota-VAR
#       ESN Minnesota-VAR      H1 7.453240 7.105020      2.276382 0.022823         Yes Minnesota-VAR
#       ESN            RF      H1 7.453240 6.934338      2.273906 0.022972         Yes            RF
#      NODE       OLS-VAR      H1 7.479765 9.047031     -2.241824 0.024973         Yes          NODE
#      NODE Minnesota-VAR      H1 7.479765 7.105020      2.209749 0.027123         Yes Minnesota-VAR
#   OLS-VAR     Ridge-VAR      H1 9.047031 7.628906      2.185244 0.028871         Yes     Ridge-VAR
#      NODE            RF      H1 7.479765 6.934338      2.177475 0.029445         Yes            RF
#       ESN       OLS-VAR      H1 7.453240 9.047031     -2.167072 0.030229         Yes           ESN
#       RNN Minnesota-VAR      H1 7.380917 7.105020      2.080914 0.037442         Yes Minnesota-VAR
#       RNN            RF      H1 7.380917 6.934338      2.009104 0.044526         Yes            RF
#      FVAR       OLS-VAR      H1 7.612386 9.047031     -1.834808 0.066534          No           Tie
# Ridge-VAR            RF      H1 7.628906 6.934338      1.695432 0.089994          No           Tie
# Ridge-VAR Minnesota-VAR      H1 7.628906 7.105020      1.627958 0.103534          No           Tie
#        RF Minnesota-VAR      H1 6.934338 7.105020     -1.381638 0.167083          No           Tie
#       RNN          FVAR      H1 7.380917 7.612386     -1.093895 0.274001          No           Tie
#       RNN           ESN      H1 7.380917 7.453240     -1.075953 0.281948          No           Tie
#       RNN     Ridge-VAR      H1 7.380917 7.628906     -0.956357 0.338892          No           Tie
#      FVAR           ESN      H1 7.612386 7.453240      0.939750 0.347346          No           Tie
#      NODE          FVAR      H1 7.479765 7.612386     -0.616087 0.537837          No           Tie
#      NODE     Ridge-VAR      H1 7.479765 7.628906     -0.596798 0.550642          No           Tie
#       ESN     Ridge-VAR      H1 7.453240 7.628906     -0.567223 0.570562          No           Tie
#      NODE           ESN      H1 7.479765 7.453240      0.352710 0.724306          No           Tie
#      FVAR     Ridge-VAR      H1 7.612386 7.628906     -0.040202 0.967932          No           Tie
#
# ====================================================================================================
# Interpretation:
#   • Friedman    : Tests whether ANY models differ significantly.
#   • DM tests    : Identifies which specific pairs differ.
#   • DM stat < 0 : Model 1 better;  DM stat > 0 : Model 2 better.
# ====================================================================================================
#
# CPIAUCSL
#
# ====================================================================================================
# STATISTICAL SIGNIFICANCE TESTS
#   Target  : Target 1
#   Horizon : H1
# ====================================================================================================
#
# 1. FRIEDMAN TEST  (Non-parametric, multiple models)
# ----------------------------------------------------------------------------------------------------
# Statistic : 17.7727
# p-value   : 0.0130  →  ✓ Significant (α=0.05)
#
# Mean Ranks (lower = better):
#         Model  Mean Rank  Mean RMSE
# Minnesota-VAR   3.227273   0.566159
#            RF   3.727273   0.796318
#          NODE   4.227273   0.869352
#           ESN   4.227273   0.838339
#     Ridge-VAR   4.681818   0.986873
#           RNN   4.727273   0.782050
#          FVAR   5.500000   1.988672
#       OLS-VAR   5.681818   1.904203
#
#
# 2. DIEBOLD-MARIANO PAIRWISE TESTS
# ----------------------------------------------------------------------------------------------------
#   Model 1       Model 2 Horizon  RMSE M1  RMSE M2  DM Statistic  p-value Significant        Winner
# Ridge-VAR Minnesota-VAR      H1 1.176317 0.762778      2.718489 0.006558         Yes Minnesota-VAR
#       RNN Minnesota-VAR      H1 0.941268 0.762778      2.421211 0.015469         Yes Minnesota-VAR
#       ESN Minnesota-VAR      H1 1.094262 0.762778      2.182426 0.029078         Yes Minnesota-VAR
#      FVAR Minnesota-VAR      H1 2.844178 0.762778      2.090298 0.036591         Yes Minnesota-VAR
#      FVAR     Ridge-VAR      H1 2.844178 1.176317      2.006209 0.044834         Yes     Ridge-VAR
#       RNN          FVAR      H1 0.941268 2.844178     -2.001163 0.045375         Yes           RNN
#      FVAR            RF      H1 2.844178 1.042352      1.976424 0.048107         Yes            RF
#      NODE          FVAR      H1 1.083455 2.844178     -1.958619 0.050157          No           Tie
#      FVAR           ESN      H1 2.844178 1.094262      1.933339 0.053194          No           Tie
#      NODE Minnesota-VAR      H1 1.083455 0.762778      1.682080 0.092553          No           Tie
#        RF Minnesota-VAR      H1 1.042352 0.762778      1.622868 0.104618          No           Tie
#   OLS-VAR Minnesota-VAR      H1 2.999420 0.762778      1.553838 0.120223          No           Tie
#      NODE       OLS-VAR      H1 1.083455 2.999420     -1.524763 0.127318          No           Tie
#   OLS-VAR            RF      H1 2.999420 1.042352      1.516074 0.129501          No           Tie
#       RNN       OLS-VAR      H1 0.941268 2.999420     -1.507572 0.131664          No           Tie
#       ESN       OLS-VAR      H1 1.094262 2.999420     -1.501502 0.133226          No           Tie
#       RNN     Ridge-VAR      H1 0.941268 1.176317     -1.486662 0.137104          No           Tie
#   OLS-VAR     Ridge-VAR      H1 2.999420 1.176317      1.416026 0.156768          No           Tie
#       RNN           ESN      H1 0.941268 1.094262     -1.217743 0.223322          No           Tie
#       RNN          NODE      H1 0.941268 1.083455     -0.922106 0.356473          No           Tie
#       ESN            RF      H1 1.094262 1.042352      0.851045 0.394744          No           Tie
#      NODE            RF      H1 1.083455 1.042352      0.807613 0.419313          No           Tie
#       RNN            RF      H1 0.941268 1.042352     -0.717214 0.473242          No           Tie
# Ridge-VAR            RF      H1 1.176317 1.042352      0.714835 0.474711          No           Tie
#      NODE     Ridge-VAR      H1 1.083455 1.176317     -0.475602 0.634358          No           Tie
#       ESN     Ridge-VAR      H1 1.094262 1.176317     -0.474938 0.634831          No           Tie
#      NODE           ESN      H1 1.083455 1.094262     -0.186615 0.851963          No           Tie
#      FVAR       OLS-VAR      H1 2.844178 2.999420     -0.153334 0.878135          No           Tie
#
# ====================================================================================================
# Interpretation:
#   • Friedman    : Tests whether ANY models differ significantly.
#   • DM tests    : Identifies which specific pairs differ.
#   • DM stat < 0 : Model 1 better;  DM stat > 0 : Model 2 better.
# ====================================================================================================
#
# UNRATE
#
# ====================================================================================================
# STATISTICAL SIGNIFICANCE TESTS
#   Target  : Target 2
#   Horizon : H1
# ====================================================================================================
#
# 1. FRIEDMAN TEST  (Non-parametric, multiple models)
# ----------------------------------------------------------------------------------------------------
# Statistic : 23.3485
# p-value   : 0.0015  →  ✓ Significant (α=0.05)
#
# Mean Ranks (lower = better):
#         Model  Mean Rank  Mean RMSE
#           RNN   2.954545   3.770236
#          NODE   3.772727   3.914433
#           ESN   3.863636   3.936797
#            RF   4.409091   4.068361
# Minnesota-VAR   4.545455   4.237431
#       OLS-VAR   5.227273   4.546243
#          FVAR   5.500000   5.334581
#     Ridge-VAR   5.727273   4.579284
#
#
# 2. DIEBOLD-MARIANO PAIRWISE TESTS
# ----------------------------------------------------------------------------------------------------
#   Model 1       Model 2 Horizon   RMSE M1   RMSE M2  DM Statistic  p-value Significant Winner
#      FVAR Minnesota-VAR      H1 12.576897 12.304637      1.546801 0.121911          No    Tie
#       RNN          NODE      H1 12.293648 12.363816     -1.463871 0.143229          No    Tie
#      FVAR       OLS-VAR      H1 12.576897 12.160051      1.380248 0.167510          No    Tie
# Ridge-VAR            RF      H1 12.457169 12.295756      1.202528 0.229159          No    Tie
#       RNN           ESN      H1 12.293648 12.418237     -1.139455 0.254513          No    Tie
#      FVAR            RF      H1 12.576897 12.295756      1.119004 0.263138          No    Tie
# Ridge-VAR Minnesota-VAR      H1 12.457169 12.304637      1.117053 0.263972          No    Tie
#       RNN     Ridge-VAR      H1 12.293648 12.457169     -1.059483 0.289380          No    Tie
#       RNN          FVAR      H1 12.293648 12.576897     -0.996976 0.318776          No    Tie
#      NODE           ESN      H1 12.363816 12.418237     -0.859177 0.390243          No    Tie
#   OLS-VAR     Ridge-VAR      H1 12.160051 12.457169     -0.849653 0.395518          No    Tie
#       ESN            RF      H1 12.418237 12.295756      0.842747 0.399370          No    Tie
#      NODE            RF      H1 12.363816 12.295756      0.825255 0.409227          No    Tie
#      NODE          FVAR      H1 12.363816 12.576897     -0.678831 0.497245          No    Tie
#      FVAR     Ridge-VAR      H1 12.576897 12.457169      0.673643 0.500538          No    Tie
#   OLS-VAR Minnesota-VAR      H1 12.160051 12.304637     -0.563498 0.573096          No    Tie
#      NODE     Ridge-VAR      H1 12.363816 12.457169     -0.510969 0.609373          No    Tie
#       ESN       OLS-VAR      H1 12.418237 12.160051      0.483129 0.629004          No    Tie
#      FVAR           ESN      H1 12.576897 12.418237      0.430764 0.666640          No    Tie
#      NODE       OLS-VAR      H1 12.363816 12.160051      0.428823 0.668052          No    Tie
#   OLS-VAR            RF      H1 12.160051 12.295756     -0.339256 0.734417          No    Tie
#       ESN Minnesota-VAR      H1 12.418237 12.304637      0.317057 0.751200          No    Tie
#       RNN       OLS-VAR      H1 12.293648 12.160051      0.309180 0.757184          No    Tie
#      NODE Minnesota-VAR      H1 12.363816 12.304637      0.195372 0.845102          No    Tie
#       ESN     Ridge-VAR      H1 12.418237 12.457169     -0.164822 0.869084          No    Tie
#       RNN            RF      H1 12.293648 12.295756     -0.053112 0.957643          No    Tie
#       RNN Minnesota-VAR      H1 12.293648 12.304637     -0.041473 0.966919          No    Tie
#        RF Minnesota-VAR      H1 12.295756 12.304637     -0.036980 0.970501          No    Tie
#
# ====================================================================================================
# Interpretation:
#   • Friedman    : Tests whether ANY models differ significantly.
#   • DM tests    : Identifies which specific pairs differ.
#   • DM stat < 0 : Model 1 better;  DM stat > 0 : Model 2 better.
# ====================================================================================================
#
# GS10
#
# ====================================================================================================
# STATISTICAL SIGNIFICANCE TESTS
#   Target  : Target 3
#   Horizon : H1
# ====================================================================================================
#
# 1. FRIEDMAN TEST  (Non-parametric, multiple models)
# ----------------------------------------------------------------------------------------------------
# Statistic : 25.3182
# p-value   : 0.0007  →  ✓ Significant (α=0.05)
#
# Mean Ranks (lower = better):
#         Model  Mean Rank  Mean RMSE
#            RF   3.272727   0.450699
#          NODE   3.409091   0.481269
#           ESN   4.000000   0.510624
#           RNN   4.136364   0.600468
# Minnesota-VAR   4.772727   0.844626
#     Ridge-VAR   4.772727   0.882370
#          FVAR   5.500000   1.531405
#       OLS-VAR   6.136364   1.777330
#
#
# 2. DIEBOLD-MARIANO PAIRWISE TESTS
# ----------------------------------------------------------------------------------------------------
#   Model 1       Model 2 Horizon  RMSE M1  RMSE M2  DM Statistic  p-value Significant        Winner
#   OLS-VAR            RF      H1 2.268956 0.647397      2.724068 0.006448         Yes            RF
#      NODE       OLS-VAR      H1 0.661907 2.268956     -2.712116 0.006686         Yes          NODE
#       ESN       OLS-VAR      H1 0.694344 2.268956     -2.687180 0.007206         Yes           ESN
#       RNN       OLS-VAR      H1 0.783003 2.268956     -2.669988 0.007585         Yes           RNN
#   OLS-VAR Minnesota-VAR      H1 2.268956 1.117249      2.252797 0.024272         Yes Minnesota-VAR
#        RF Minnesota-VAR      H1 0.647397 1.117249     -1.988379 0.046770         Yes            RF
#      NODE Minnesota-VAR      H1 0.661907 1.117249     -1.982827 0.047387         Yes          NODE
#      FVAR     Ridge-VAR      H1 2.174196 1.319589      1.922585 0.054532          No           Tie
#      FVAR            RF      H1 2.174196 0.647397      1.864768 0.062214          No           Tie
#      NODE          FVAR      H1 0.661907 2.174196     -1.860646 0.062794          No           Tie
#       ESN Minnesota-VAR      H1 0.694344 1.117249     -1.856370 0.063401          No           Tie
#      FVAR           ESN      H1 2.174196 0.694344      1.842629 0.065383          No           Tie
#       RNN          FVAR      H1 0.783003 2.174196     -1.786606 0.074001          No           Tie
#      FVAR Minnesota-VAR      H1 2.174196 1.117249      1.768667 0.076949          No           Tie
#   OLS-VAR     Ridge-VAR      H1 2.268956 1.319589      1.717488 0.085890          No           Tie
#       RNN          NODE      H1 0.783003 0.661907      1.697694 0.089566          No           Tie
# Ridge-VAR            RF      H1 1.319589 0.647397      1.635593 0.101925          No           Tie
#      NODE     Ridge-VAR      H1 0.661907 1.319589     -1.621645 0.104879          No           Tie
#       RNN            RF      H1 0.783003 0.647397      1.608851 0.107649          No           Tie
#       RNN Minnesota-VAR      H1 0.783003 1.117249     -1.580401 0.114015          No           Tie
#       ESN     Ridge-VAR      H1 0.694344 1.319589     -1.577602 0.114657          No           Tie
#       RNN     Ridge-VAR      H1 0.783003 1.319589     -1.410062 0.158521          No           Tie
#      NODE           ESN      H1 0.661907 0.694344     -1.368588 0.171128          No           Tie
#       ESN            RF      H1 0.694344 0.647397      1.299323 0.193833          No           Tie
#       RNN           ESN      H1 0.783003 0.694344      1.263858 0.206281          No           Tie
# Ridge-VAR Minnesota-VAR      H1 1.319589 1.117249      0.936599 0.348965          No           Tie
#      NODE            RF      H1 0.661907 0.647397      0.536076 0.591906          No           Tie
#      FVAR       OLS-VAR      H1 2.174196 2.268956     -0.141888 0.887169          No           Tie
#
# ====================================================================================================
# Interpretation:
#   • Friedman    : Tests whether ANY models differ significantly.
#   • DM tests    : Identifies which specific pairs differ.
#   • DM stat < 0 : Model 1 better;  DM stat > 0 : Model 2 better.
# ====================================================================================================
